# %%
using Plots
plot(1:10)
# Out:
# (process:7904): GLib-GIO-WARNING **: 10:23:21.678: Unexpectedly, UWP app `KDEe.V.Okular_20.1202.546.0_x64__7vt06qxq7ptv8' (AUMId `KDEe.V.Okular_7vt06qxq7ptv8!KDEe.V.Okular') supports 5 extensions but has no verbs

# %%
using DelimitedFiles
table = readdlm("valSimuls/z-a16-ts_table.csv",',')
# Out:
# 51×24 Matrix{Float64}:
#    1092.0    1579.0     269.0     501.0  …     260.0     607.0     371.0
#     270.0     822.0     350.0     224.0       1740.0     284.0     329.0
#    2024.0     644.0     296.0     709.0        893.0    1763.0     684.0
#    1155.0     538.0     373.0     447.0        722.0     607.0     959.0
#     966.0    1575.0     584.0     433.0       1261.0    2366.0     841.0
#     445.0     508.0     397.0     450.0  …    1056.0    1875.0    2996.0
#    1697.0     258.0    1940.0    1369.0        915.0     529.0     133.0
#     521.0    1536.0    1395.0    2047.0       2658.0     599.0     302.0
#    1095.0    2183.0     603.0     710.0       1312.0    1185.0     382.0
#    1138.0     922.0     405.0     314.0        633.0     531.0     584.0
#    1222.0    1294.0     629.0    1092.0  …    3400.0     307.0    1749.0
#    1293.0     639.0    1408.0    1356.0       1080.0    3035.0     916.0
#     735.0    1100.0    1337.0    1611.0       1862.0     475.0    1674.0
# ...

# %%
ls = range(1,stop=1.25,length=51)
# Out:
# 1.0:0.005:1.25

# %%
using Statistics

# %%
table[:,1]
# Out:
# 51-element Vector{Float64}:
#    1092.0
#     270.0
#    2024.0
#    1155.0
#     966.0
#     445.0
#    1697.0
#     521.0
#    1095.0
#    1138.0
#    1222.0
#    1293.0
#     735.0
#       ⋮
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0
#  100000.0

# %%
ys = [1/mean(table[i,:]) for i in 1:51]
# Out:
# 51-element Vector{Float64}:
#  0.001197724323784809
#  0.0015261350629530714
#  0.0010365379632029023
#  0.0009891604500680048
#  0.0009632751354605659
#  0.0008056394763343404
#  0.0009007656508031826
#  0.0009523809523809524
#  0.0008751458576429404
#  0.0010995555962798368
#  0.0007542663188660863
#  0.0008230734936040331
#  0.0007913740231476902
#  ⋮
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5
#  1.0e-5

# %%
scatter(ls,ys)
