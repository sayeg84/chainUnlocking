# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
scatter(1:10)

# %%
?savefig
# Out:
# search: savefig StackOverflowError
#   savefig([plot,] filename)
#
#   Save a Plot (the current plot if plot is not passed) to file. The file type
#   is inferred from the file extension. All backends support png and pdf file
#   types, some also support svg, ps, eps, html and tex.

# %%
include("../src/test.jl")
# Out:
# WARNING: redefinition of constant ex. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ey. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ez. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant e0. This may fail, cause incorrect answers, or produce other errors.

# %%
p = plot(aspect_ratio=1,figsize=(600,600))
q1 = 0.2*ex + 0.6*ey
q2 = 2*ex + ey
theta = pi/2*rand()
plotLine!(q1,q2,lw=3,label="segmento")
plotRotation!(q1,q2,theta)
plotCircle!(e0,norm(q1))
plotCircle!(e0,norm(q2))
p1 = -0.8*ex+ey
p2 = 1.2*ey
#plotLine!(p1,p2,lw=3,label="segmento")

#p1 = zrotation(theta/3)*q1
#p2 = zrotation(theta/3)*q2
#vp = p2 - p1
#p1 = p1 + 0.6*vp
#p2 = p2 + 0.6*vp
plot!(legend=false)
c = 2.4
xlims!(-c,c)
ylims!(-c,c)
savefig(joinpath("..","..","tesisMaestriaAldo","figs","simulacion","rot1.pdf"))
p

# %%
p = plot(aspect_ration=1)
q1 = 0.3*ex + ey
q2 = 0.3*ex - ey
theta = pi/2*rand()
plotLine!(q1,q2,lw=3,label="segmento")
plotRotation!(q1,q2,theta)
plotCircle!(e0,norm(q1))
plotCircle!(e0,norm(q2))
p1 = -0.8*ex+ey
p2 = 1.2*ey
#plotLine!(p1,p2,lw=3,label="segmento")

#p1 = zrotation(theta/3)*q1
#p2 = zrotation(theta/3)*q2
#vp = p2 - p1
#p1 = p1 + 0.6*vp
#p2 = p2 + 0.6*vp
plot!(legend=false)
c = 1.1
xlims!(-c,c)
ylims!(-c,c)
savefig(joinpath("..","..","tesisMaestriaAldo","figs","simulacion","rot2.pdf"))
p

# %%
case3Intersection(p1,p2,p2-p1,q1,q2,q2-q1,theta)
# Out:
# true

# %%
include("../src/simulations.jl")
# Out:
# localSearchRandom (generic function with 4 methods)

# %%
p1 = e0
p2 = ex
p3 = ex + ey
p4 = p3 + ez
p5 = p4 - ex
p6 = p5 - ey
points = [p1,p2,p3,p4,p5,p6]
#points = [p + 0.05*2*(Point()-(ex+ey+ez)) for p in points]
Q = stair(5)
#P = PolygonalNew([p + 0.05*2*(Point()-(ex+ey+ez)) for p in points])
P = PolygonalNew(points)
p = plot()
#plotChain!(P,"red")
#plotChain!(Q,"blue")

# %%
include("../src/simulations.jl")
# Out:
# localSearchRandom (generic function with 4 methods)

# %%
lastQ,angles,diheds = localSearchRandom(P,Q,1e-4,pi/10,-pi/10)
changes = [i for i in 1:length(diheds) if diheds[i] != 0]
# Out:
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# WARNING: segments intersect before rotating
# 28-element Array{Int64,1}:
#    3
#   26
#   53
#   54
#   56
#   57
#   63
#   76
#   89
#   90
#   91
#   96
#   98
#    ⋮
#  116
#  117
#  132
#  135
#  136
#  173
#  180
#  208
#  233
#  304
#  418
#  683

# %%
p = plot()
P = centerChain(P)
lastQ = centerChain(lastQ)
OR = optimalRotation(P,lastQ)
P = PolygonalNew([OR*p for p in P.vertices])
plotChain!(P,"red")
plotChain!(Q,"blue")
plotChain!(lastQ,"lightblue")
overlapedRmsd(P,lastQ)
p

# %%
#=
aux = copy(Q)
anim = @animate for i in changes
    p = plot()
    plotChain!(aux,"blue")
    dihedralRotate!(aux,diheds[i],angles[i])
    xlims!(0,2)
    ylims!(0,2)
    zlims!(0,2)
end
gif(anim,"basico.gif",fps=20)
=#

# %%
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
Q = knittingNeedle(2)
lenghts,bangles,dangles = lengthsAndAngles(Q)
P = PolygonalOld(lenghts,bangles,[pi for t in dangles])
P = PolygonalNew([p for p in P.vertices])
#plotChain!(Q,"blue")
# Out:
# PolygonalNew(Point[Point(0.0, 0.0, 0.0), Point(1.9999999999999998, 0.0, 0.0), Point(1.268692864398084, 0.6820482925847123, 0.0), Point(1.9507411569827964, 1.413355428186628, 1.2246467991473535e-16), Point(1.2194340213808808, 2.0954037207713405, -4.930380657631324e-32), Point(3.217696397208621, 2.178755249559216, 5.207477146175737e-16)])

# %%
lastQ,angles,diheds = localSearchRandom(P,Q,1e-3,pi/10,-pi/10,max_iter=10000)
changes = [i for i in 1:length(diheds) if diheds[i] != 0];

# %%
p = plot()
plotChain!(P,"red")
plotChain!(Q,"blue")
plotChain!(lastQ,"lightblue")

# %%
p = plot()
plotChain!(lastQ,"lightblue")

# %%
include("../src/io.jl")
# Out:
# saveSimulation (generic function with 1 method)

# %%
foldername = "prueba"
if !isdir(foldername)
    mkdir(foldername)
end
saveSimulation(joinpath(foldername,"l2"),P,Q,angles,diheds)
